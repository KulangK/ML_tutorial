# %% [markdown]
# # 제로베이스 데이터 사이언스 스쿨 EDA Level Test 1
# ## 문제 소개
# - 총 3단계 데이터 분석 상황 제시
#     - 1, 2단계 60점
#     - 3단계 40점
#     - 총점 100점
# <br></br>
# - 1단계 DataFrame 불러오기 & 전처리
# - 2단계 원하는 정보 얻기
# - 3단계 시각화
# <br></br>
# ## 참고 사항
# - Check Functions 셀을 반드시 실행해주세요!
# - 여러분이 제출하신 답안을 채점하기 위한 코드입니다.
# - 각 문제마다 반드시, check_01_01(df) 함수를 실행해주시기를 바랍니다
# <br></br>
# - 1,2 단계는 채점 코드를 통해 채점합니다. 총 60점
# - 3단계는 채점자가 제출해주신 시각화 결과물을 직접 검토하여 채점합니다. 총 40점
# <br></br>
# - 파일 제목은 [DS]edatest_honggildong.ipynb 으로 제출해주시기 바랍니다.
#     - 성부터 소문자로 작성해주세요.
# - 제출은 제공드린 구글설문지를 통해 제출해주시면 감사하겠습니다.
# ---

# %% [markdown]
# # 1. Check Functions
# - grading 채점 코드 안에는 각 문제 번호에 따른 check_00_00() 라는 함수가 있습니다.
#
#     ```
#     from grading import check_01_01
#     from grading import check_01_02
#     from grading import check_01_03
#     from grading import check_02_01
#     from grading import check_02_02
#     from grading import check_02_03
#     from grading import check_02_04
#     from grading import check_02_05
#     ```
#
# - 답안을 작성하신 후에 반드시 채점 코드까지 결과값까지 포함하여 제출해주시기를 바랍니다.
#
# ex)
# check_01_01(df)
#
# 정답입니다! 10점 누적 되었습니다!
#
# 현재 누적 점수: 10 / 100

# %%
# 채점을 위한 코드입니다. 반드시 실행해주세요.
from grading import *

# %% [markdown]
# # 2. Download Target Data

# %% [markdown]
# ##### Data 출처
# - Source: [서울시 열린데이터](https://data.seoul.go.kr/dataList/419/S/2/datasetView.do)
# - Data Download: [PinkWink Blog](https://pinkwink.kr/attachment/cfile1.uf@99740C3A5ECB0EA52889B3.txt)
#
# ##### 참고사항
# * 데이터에 콤마(,)가 많아 CSV로 변환이 곤란하여, 탭으로 구분하여 TXT로 제공합니다
# * 외국인 세대수 제외
# * 65세이상 고령자 수: 외국인 포함

# %%
# Load DataFrame
import pandas as pd

df_target = pd.read_csv('./datas/report.txt', sep='\t')
df_target.head()
# Out:
#          기간  자치구         세대          인구       인구.1       인구.2       인구.3  \
# 0        기간  자치구         세대          합계         합계         합계        한국인
# 1        기간  자치구         세대           계         남자         여자          계
# 2  2020.1/4   합계  4,354,006  10,013,781  4,874,995  5,138,786  9,733,655
# 3  2020.1/4  종로구     74,151     161,984     78,271     83,713    151,217
# 4  2020.1/4   중구     63,045     136,469     66,769     69,700    126,175
#
#         인구.4       인구.5     인구.6     인구.7     인구.8  세대당인구   65세이상고령자
# 0        한국인        한국인    등록외국인    등록외국인    등록외국인  세대당인구   65세이상고령자
# 1         남자         여자        계       남자       여자  세대당인구   65세이상고령자
# 2  4,742,217  4,991,438  280,126  132,778  147,348   2.24  1,518,239
# 3     73,704     77,513   10,767    4,567    6,200   2.04     28,073
# 4     61,839     64,336   10,294    4,930    5,364      2     23,794

# %% [markdown]
# # 3. 문제

# %% [markdown]
# ## 1단계: DataFrame 불러오기 & 전처리
# ***

# %% [markdown]
# ### **문제 1-1)** 0, 1, 2번 index의 row를 제거하고 index를 초기화 하세요(기존 index는 삭제(drop)하세요).    (10점)
#
# - 예시: 0,1,2번 index 제거
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-1-1-001.png" style="margin:auto" width=130/>
#     <img src="./[문제보기용 이미지]images/01-1-1-002.png" style="margin:auto" width=180 height=180/>
#
# - 예시: index 초기화
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-1-1-002.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-1-1-003.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_01_01 함수에 입력하여 채점하세요.

# %%
df_target_new = df_target.drop(index = [0, 1, 2])
df_target_new = df_target_new.reset_index()
df_target_new = df_target_new.drop(columns='index')
df_target_new.head()
# Out:
#          기간  자치구       세대       인구     인구.1     인구.2     인구.3     인구.4  \
# 0  2020.1/4  종로구   74,151  161,984   78,271   83,713  151,217   73,704
# 1  2020.1/4   중구   63,045  136,469   66,769   69,700  126,175   61,839
# 2  2020.1/4  용산구  110,895  246,165  119,961  126,204  229,579  110,667
# 3  2020.1/4  성동구  135,643  307,193  149,891  157,302  299,042  146,300
# 4  2020.1/4  광진구  165,287  365,990  176,226  189,764  350,417  169,568
#
#       인구.5    인구.6   인구.7   인구.8 세대당인구 65세이상고령자
# 0   77,513  10,767  4,567  6,200  2.04   28,073
# 1   64,336  10,294  4,930  5,364     2   23,794
# 2  118,912  16,586  9,294  7,292  2.07   39,439
# 3  152,742   8,151  3,591  4,560   2.2   44,728
# 4  180,849  15,573  6,658  8,915  2.12   48,989

# %%
check_01_01(df_target_new)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 10 / 60

# %% [markdown]
# ### **문제 1-2)** 현재의 컬럼명(current_columns)을 아래 new_columns와 같이 변경하세요.      (10점)
#
# - current_columns = ['기간', '자치구', '세대', '인구', '인구.1', '인구.2', '인구.3', '인구.4', '인구.5', '인구.6', '인구.7', '인구.8', '세대당인구', '65세이상고령자']
# <br></br>
# - new_columns = ['기간', '자치구', '세대', '합계', '남자', '여자', '한국인 계', '한국인 남자', '한국인 여자', '등록외국인 계', '등록외국인 남자', '등록외국인 여자', '세대당인구', '65세이상고령자']
# <br></br>
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-1-2-001.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-1-2-002.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_01_02 함수에 입력하여 채점하세요.

# %%
current_columns = ['기간', '자치구', '세대', '인구', '인구.1', '인구.2', '인구.3', '인구.4', '인구.5', '인구.6', '인구.7', '인구.8', '세대당인구', '65세이상고령자']

new_columns = ['기간', '자치구', '세대', '합계', '남자', '여자', '한국인 계', '한국인 남자', '한국인 여자', '등록외국인 계', '등록외국인 남자', '등록외국인 여자', '세대당인구', '65세이상고령자']

for x in range(len(current_columns)):
    df_target_new.rename(columns={current_columns[x] : new_columns[x]}, inplace=True)

df_target_new.head()
# Out:
#          기간  자치구       세대       합계       남자       여자    한국인 계   한국인 남자  \
# 0  2020.1/4  종로구   74,151  161,984   78,271   83,713  151,217   73,704
# 1  2020.1/4   중구   63,045  136,469   66,769   69,700  126,175   61,839
# 2  2020.1/4  용산구  110,895  246,165  119,961  126,204  229,579  110,667
# 3  2020.1/4  성동구  135,643  307,193  149,891  157,302  299,042  146,300
# 4  2020.1/4  광진구  165,287  365,990  176,226  189,764  350,417  169,568
#
#     한국인 여자 등록외국인 계 등록외국인 남자 등록외국인 여자 세대당인구 65세이상고령자
# 0   77,513  10,767    4,567    6,200  2.04   28,073
# 1   64,336  10,294    4,930    5,364     2   23,794
# 2  118,912  16,586    9,294    7,292  2.07   39,439
# 3  152,742   8,151    3,591    4,560   2.2   44,728
# 4  180,849  15,573    6,658    8,915  2.12   48,989

# %%
check_01_02(df_target_new)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 20 / 60

# %% [markdown]
# ### **문제 1-3)** 천단위 구분자 " , "를 제거하고, data의 type을 int 또는 float으로 변경하세요.   (10점)
# - 기간, 자치구: 변경 없음
# <br></br>
# - '세대', '합계', '남자', '여자', '한국인 계', '한국인 남자', '한국인 여자', '등록외국인 계', '등록외국인 남자', '등록외국인 여자', '65세이상고령자': 천단위 구분자 "," 제거 및 int로 타입 변경
# <br></br>
#     - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-1-3-001.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-1-3-002.png" style="margin:auto" width=150/>
# <br></br>
# - '세대당인구': float으로 타입 변경
# <br></br>
#     - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-1-3-003.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-1-3-004.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_01_03 함수에 입력하여 채점하세요.

# %%
for x in range(len(new_columns)):
    df_target_new[new_columns[x]] = df_target_new[new_columns[x]].str.replace(',', '')

df_target_new.head()
# Out:
#          기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 0  2020.1/4  종로구   74151  161984   78271   83713  151217   73704   77513
# 1  2020.1/4   중구   63045  136469   66769   69700  126175   61839   64336
# 2  2020.1/4  용산구  110895  246165  119961  126204  229579  110667  118912
# 3  2020.1/4  성동구  135643  307193  149891  157302  299042  146300  152742
# 4  2020.1/4  광진구  165287  365990  176226  189764  350417  169568  180849
#
#   등록외국인 계 등록외국인 남자 등록외국인 여자 세대당인구 65세이상고령자
# 0   10767     4567     6200  2.04    28073
# 1   10294     4930     5364     2    23794
# 2   16586     9294     7292  2.07    39439
# 3    8151     3591     4560   2.2    44728
# 4   15573     6658     8915  2.12    48989

# %%
for x in range(len(new_columns)):
    if x < 2:
        continue
    if x == 12:
        df_target_new[new_columns[x]] = df_target_new[new_columns[x]].astype(float)
        continue
    df_target_new[new_columns[x]] = df_target_new[new_columns[x]].astype('int64')

# %%
df_target_new.dtypes
# Out:
# 기간           object
# 자치구          object
# 세대            int64
# 합계            int64
# 남자            int64
# 여자            int64
# 한국인 계         int64
# 한국인 남자        int64
# 한국인 여자        int64
# 등록외국인 계       int64
# 등록외국인 남자      int64
# 등록외국인 여자      int64
# 세대당인구       float64
# 65세이상고령자      int64
# dtype: object

# %%
check_01_03(df_target_new)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 30 / 60

# %% [markdown]
# ## 2단계: 원하는 정보 얻기

# %% [markdown]
# ### *Pandas DataFrame의 기능을 이용하여 아래 문제의 답을 구하세요.*
# ***
# #### 서울시는 아래와 같이 5개의 권역으로 구분됩니다.
# ![서울시 권역생활권](https://www.seoulsolution.kr/sites/default/files/images/%EC%B2%B4%EA%B3%846.jpg)
# - ref: [서울시-도시계획체계](https://www.seoulsolution.kr/ko/content/서울시-도시계획체계)
#
# - 도심권: ['종로구', '중구', '용산구']
# - 동북권: ['성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구']
# - 서북권: ['은평구', '서대문구', '마포구']
# - 서남권: ['양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구']
# - 동남권: ['서초구', '강남구', '송파구', '강동구']
# ***

# %%
region_dict = {'도심권': ['종로구', '중구', '용산구'],
               '동북권': ['성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구'],
               '서북권': ['은평구', '서대문구', '마포구'],
               '서남권': ['양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구'],
               '동남권': ['서초구', '강남구', '송파구', '강동구']
               }

# %% [markdown]
# ### **문제 2-1)** 1단계에서 구한 DataFrame에 '권역' column을 추가하여 해당 구에 맞는 권역을 입력하세요.    (5점)
#
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-2-1-001.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-2-1-002.png" style="margin:auto" width=200/>
#
# - 완료 후 결과 dataframe 변수를 check_02_01 함수에 입력하여 채점하세요.

# %%
df_target_new['권역'] = np.nan

for idx, row in df_target_new.iterrows():
    for x in region_dict.keys():
        if df_target_new['자치구'][idx] in region_dict[x]:
            df_target_new['권역'][idx] = x

df_target_new.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8812\648105873.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_target_new['권역'][idx] = x
#          기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 0  2020.1/4  종로구   74151  161984   78271   83713  151217   73704   77513
# 1  2020.1/4   중구   63045  136469   66769   69700  126175   61839   64336
# 2  2020.1/4  용산구  110895  246165  119961  126204  229579  110667  118912
# 3  2020.1/4  성동구  135643  307193  149891  157302  299042  146300  152742
# 4  2020.1/4  광진구  165287  365990  176226  189764  350417  169568  180849
#
#    등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역
# 0    10767      4567      6200   2.04     28073  도심권
# 1    10294      4930      5364   2.00     23794  도심권
# 2    16586      9294      7292   2.07     39439  도심권
# 3     8151      3591      4560   2.20     44728  동북권
# 4    15573      6658      8915   2.12     48989  동북권

# %%
check_02_01(df_target_new)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 35 / 60

# %% [markdown]
# ### **문제 2-2)** 2-1에서 만든 DataFrame을 이용하여 Pandas의 pivot_table 메소드를 활용하여 각 권역별 아래 값의 합을 구하고, '합계'를 기준으로 내림차순 정렬하세요.      (5점)
#
# - 구할 값: ['합계', '세대', '여자', '한국인 계', '등록외국인 계', '65세이상고령자']
#
# - 참고: [Pivot Table](https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html)
# <br></br>
#     - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-2-2-001.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-2-2-002.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_02_02 함수에 입력하여 채점하세요.

# %%
df_target_new1 = df_target_new.pivot_table(
    index=["권역"],
    values=["65세이상고령자", "등록외국인 계", "세대", "여자", "한국인 계", "합계"],
    aggfunc=[np.sum],
)

df_target_new1.sort_values(('sum', '합계'), ascending=False, inplace=True)
df_target_new1 = df_target_new1.droplevel(0, axis=1)
# df_target_new1 = df_target_new1[["합계", "한국인 계", "여자", "세대", "등록외국인 계", "65세이상고령자"]]
df_target_new1
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계
# 권역
# 동북권    497385    67938  1342778  1580313  3008988  3076926
# 서남권    454108   124791  1360162  1554745  2950352  3075143
# 동남권    286874    20511   876524  1097300  2102113  2122624
# 서북권    188566    29239   526451   626811  1165231  1194470
# 도심권     91306    37647   248091   279617   506971   544618

# %%
check_02_02(df_target_new1)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 40 / 60

# %% [markdown]
# ### **문제 2-3)** 2-2에서 만든 Pivot Table을 이용하여 각 권역별 ['고령자비율', '외국인비율', '여성비율', '세대당인구'] 컬럼을 만들어 아래와 같이 값을 입력하고 '외국인비율'을 기준으로 오름차순 정렬하세요.  (5점)
#
# - 고령자비율: 65세이상고령자 / 합계 * 100
#
# - 외국인비율: 등록외국인 계 / 합계 * 100
#
# - 여성비율: 여자 / 합계 * 100
#
# - 세대당인구: (합계 - 등록외국인 계) / 세대
# <br></br>
# - 예시: B/C 비율 및  B 기준 오름차순 정렬
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-2-2-002.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-2-3-001.png" style="margin:auto" width=230/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_02_03 함수에 입력하여 채점하세요.

# %%
df_target_new1['고령자비율'] = np.nan
df_target_new1['외국인비율'] = np.nan
df_target_new1['여성비율'] = np.nan
df_target_new1['세대당인구'] = np.nan

for idx, row in df_target_new1.iterrows():
    df_target_new1['고령자비율'][idx] = df_target_new1['65세이상고령자'][idx] / df_target_new1['합계'][idx] * 100
    df_target_new1['외국인비율'][idx] = df_target_new1['등록외국인 계'][idx] / df_target_new1['합계'][idx] * 100
    df_target_new1['여성비율'][idx] = df_target_new1['여자'][idx] / df_target_new1['합계'][idx] * 100
    df_target_new1['세대당인구'][idx] = (df_target_new1['합계'][idx] - df_target_new1['등록외국인 계'][idx]) / df_target_new1['세대'][idx]

df_target_new1.sort_values(('외국인비율'), ascending=True, inplace=True)

df_target_new1
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8812\1856409421.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_target_new1['고령자비율'][idx] = df_target_new1['65세이상고령자'][idx] / df_target_new1['합계'][idx] * 100
# C:\Users\User\AppData\Local\Temp\ipykernel_8812\1856409421.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_target_new1['외국인비율'][idx] = df_target_new1['등록외국인 계'][idx] / df_target_new1['합계'][idx] * 100
# C:\Users\User\AppData\Local\Temp\ipykernel_8812\1856409421.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_target_new1['여성비율'][idx] = df_target_new1['여자'][idx] / df_target_new1['합계'][idx] * 100
# C:\Users\User\AppData\Local\Temp\ipykernel_8812\1856409421.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_target_new1['세대당인구'][idx] = (df_target_new1['합계'][idx] - df_target_new1['등록외국인 계'][idx]) / df_target_new1['세대'][idx]
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계      고령자비율  \
# 권역
# 동남권    286874    20511   876524  1097300  2102113  2122624  13.515064
# 동북권    497385    67938  1342778  1580313  3008988  3076926  16.164997
# 서북권    188566    29239   526451   626811  1165231  1194470  15.786583
# 서남권    454108   124791  1360162  1554745  2950352  3075143  14.767053
# 도심권     91306    37647   248091   279617   506971   544618  16.765145
#
#         외국인비율       여성비율     세대당인구
# 권역
# 동남권  0.966304  51.695449  2.398238
# 동북권  2.207983  51.360124  2.240868
# 서북권  2.447864  52.476077  2.213370
# 서남권  4.058055  50.558462  2.169118
# 도심권  6.912552  51.341858  2.043488

# %%
check_02_03(df_target_new1)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 45 / 60

# %% [markdown]
# ### **문제 2-4)** 2-1에서 만든 DataFrame을 이용하여 각 구별 ['고령자비율', '외국인비율', '여성비율'] 컬럼을 만들어 아래와 같이 값을 입력하고 '세대당인구'을 기준으로 내림차순 정렬하세요.  (5점)
# - 고령자비율: 65세이상고령자 / 합계 * 100
# - 외국인비율: 등록외국인 계 / 합계 * 100
# - 여성비율: 여자 / 합계 * 100
# - 완료 후 결과 dataframe 변수를 check_02_04 함수에 입력하여 채점하세요.

# %%
df_target_new['고령자비율'] = np.nan
df_target_new['외국인비율'] = np.nan
df_target_new['여성비율'] = np.nan

for idx, row in df_target_new.iterrows():
    df_target_new['고령자비율'][idx] = df_target_new['65세이상고령자'][idx] / df_target_new['합계'][idx] * 100
    df_target_new['외국인비율'][idx] = df_target_new['등록외국인 계'][idx] / df_target_new['합계'][idx] * 100
    df_target_new['여성비율'][idx] = df_target_new['여자'][idx] / df_target_new['합계'][idx] * 100

df_target_new.sort_values(('세대당인구'), ascending=False, inplace=True)

df_target_new.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8812\136196848.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_target_new['고령자비율'][idx] = df_target_new['65세이상고령자'][idx] / df_target_new['합계'][idx] * 100
# C:\Users\User\AppData\Local\Temp\ipykernel_8812\136196848.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_target_new['외국인비율'][idx] = df_target_new['등록외국인 계'][idx] / df_target_new['합계'][idx] * 100
# C:\Users\User\AppData\Local\Temp\ipykernel_8812\136196848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_target_new['여성비율'][idx] = df_target_new['여자'][idx] / df_target_new['합계'][idx] * 100
#           기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 14  2020.1/4  양천구  177436  460532  226109  234423  456339  224241  232098
# 21  2020.1/4  서초구  173580  434801  207877  226924  430568  205787  224781
# 10  2020.1/4  노원구  217148  535495  258696  276799  531037  256726  274311
# 23  2020.1/4  송파구  279301  680883  329058  351825  674095  325859  348236
# 9   2020.1/4  도봉구  138595  333495  162774  170721  331238  161879  169359
#
#     등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역      고령자비율     외국인비율  \
# 14     4193      1868      2325   2.57     62761  서남권  13.627935  0.910469
# 21     4233      2090      2143   2.48     58332  동남권  13.415793  0.973549
# 10     4458      1970      2488   2.45     82682  동북권  15.440294  0.832501
# 23     6788      3199      3589   2.41     89539  동남권  13.150424  0.996941
# 9      2257       895      1362   2.39     60023  동북권  17.998171  0.676772
#
#          여성비율
# 14  50.902652
# 21  52.190312
# 10  51.690305
# 23  51.671873
# 9   51.191472

# %%
check_02_04(df_target_new)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 50 / 60

# %% [markdown]
# ### **문제 2-5)** 2-3에서 만든 DataFrame을 이용하여 ['고령자비율', '외국인비율', '여성비율', '세대당인구']간의 피어슨 상관계수 행렬(Correlation matrix)를 구하세요. (10점)
#
# - 참고
#     - 상관계수(correlation coefficient): 두 변수가 함께 변하는 정도를 -1 ~ +1 범위의 수로 나타낸 것
#
#     - 피어슨 상관계수: 칼 피어슨(Karl Pearson)이 개발한 상관계수로, 일반적으로 상관계수라고 하면 피어슨 상관계수를 말함
#         - Standard Correlation Coefficient
#         - r(상관계수) = X와 Y가 함께 변하는 정도 / X와 Y가 각각 변하는 정도
# <br></br>
#     - 상관계수 행렬(Correlation Matrix): 변수간 상관계수를 보여주는 행렬
# <br></br>
#         - 예시: dog와 cat간의 상관계수 행렬
# <br></br>
#         <img src='./[문제보기용 이미지]images/01-2-5-001.png' width=150>
#         <img src='./[문제보기용 이미지]images/01-2-5-002.png' width=350>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_02_05 함수에 입력하여 채점하세요.

# %%
df_target_corr = df_target_new1[["고령자비율", "외국인비율", "여성비율", "세대당인구"]].corr()
df_target_corr
# Out:
#           고령자비율     외국인비율      여성비율     세대당인구
# 고령자비율  1.000000  0.655428  0.079476 -0.809536
# 외국인비율  0.655428  1.000000 -0.380941 -0.943776
# 여성비율   0.079476 -0.380941  1.000000  0.283602
# 세대당인구 -0.809536 -0.943776  0.283602  1.000000

# %%
check_02_05(df_target_corr)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 60 / 60

# %% [markdown]
# ## 3단계: 시각화

# %% [markdown]
# ### *Pandas DataFrame의 Plot기능, Matplotlib.pyplot, Seaborn 등 시각화 Library를 이용하여 문제와 같이 시각화하세요.*
# ***

# %%
# 한글 설정
import matplotlib.pyplot as plt
import koreanize_matplotlib
import seaborn as sns

# %% [markdown]
# ### **문제 3-1)** 자치구별 고령자비율을 내림차순에 따라 barh 그래프로 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-3-1-001.png" style="margin:auto" width=400/>

# %%
df_target_new.sort_values(by = "고령자비율", ascending=True, inplace=True)

plt.figure(figsize=(10,6))
plt.ylabel("자치구")
plt.title("서울시 자치구별 고령자비율")
x = np.arange(0, 20, 0.1)
y = np.arange(len(df_target_new["고령자비율"]))
plt.barh(y, df_target_new["고령자비율"])
plt.yticks(y, df_target_new["자치구"])
plt.legend(["고령자비율"])

plt.show()

# %% [markdown]
# ### **문제 3-2)** 권역별 등록외국인 계를 PIE chart로 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-3-2-001.png" style="margin:auto" width=400/>

# %%
labels = [i for i in df_target_new1.index]
sizes = [df_target_new1['등록외국인 계'][idx] for idx, rows in df_target_new1.iterrows()]
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
plt.legend(loc='lower right')

# %% [markdown]
# ### **문제 3-3)** 권역별 외국인비율을 Box plot으로 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-3-3-001.png" style="margin:auto" width=400/>

# %%
df_target_new.set_index('권역', inplace=True, drop=True)
df_target_new.head()
# Out:
#            기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 권역
# 동남권  2020.1/4  송파구  279301  680883  329058  351825  674095  325859  348236
# 동남권  2020.1/4  강남구  233624  549898  263163  286735  544804  260654  284150
# 동북권  2020.1/4  광진구  165287  365990  176226  189764  350417  169568  180849
# 동남권  2020.1/4  서초구  173580  434801  207877  226924  430568  205787  224781
# 서남권  2020.1/4  양천구  177436  460532  226109  234423  456339  224241  232098
#
#      등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자      고령자비율     외국인비율  \
# 권역
# 동남권     6788      3199      3589   2.41     89539  13.150424  0.996941
# 동남권     5094      2509      2585   2.33     72602  13.202812  0.926354
# 동북권    15573      6658      8915   2.12     48989  13.385338  4.255034
# 동남권     4233      2090      2143   2.48     58332  13.415793  0.973549
# 서남권     4193      1868      2325   2.57     62761  13.627935  0.910469
#
#           여성비율
# 권역
# 동남권  51.671873
# 동남권  52.143307
# 동북권  51.849504
# 동남권  52.190312
# 서남권  50.902652

# %%
data1 = [df_target_new['외국인비율']['동북권'], df_target_new['외국인비율']['서북권'], df_target_new['외국인비율']['동남권'], 
     df_target_new['외국인비율']['서남권'], df_target_new['외국인비율']['도심권']]
plt.figure(figsize=(10,6))
plt.boxplot(    
    data1,
    labels=['동북권', '서북권', '동남권', '서남권', '도심권']
)

plt.title("권역별 외국인 비율")
plt.xlabel("권역")
plt.ylabel("외국인비율")
plt.show()

# %% [markdown]
# ### **문제 3-4)** 자치구별 외국인비율-세대당인구를 Scatter plot에 나타내고, 상관관계에 따른 Regression Line을 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-3-4-001.png" style="margin:auto" width=400/>

# %%
fit1 = np.polyfit(df_target_new['외국인비율'], df_target_new['세대당인구'], 1)
fi1 = np.poly1d(fit1)
fx = np.linspace(0, 9, 100)

# this can be used for matplotlib scatter plot

# %%
plt.figure(figsize=(10,6))
sns.regplot(x = df_target_new['외국인비율'], y = df_target_new['세대당인구'])
plt.title('외국인비율-세대당인구 상관관계')
plt.grid()
plt.show()
